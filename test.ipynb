# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

# Define parameters
vocab_size = 5
embedding_dim = 3
max_length = 4
num_filters = 2
kernel_size = 2

# Step 1: Define the model
class ExampleTextCNN(nn.Module):
    def __init__(self):
        super(ExampleTextCNN, self).__init__()
        
        # Embedding layer with predefined weights
        self.embedding = nn.Embedding(vocab_size, embedding_dim)
        embedding_weights = torch.tensor([
            [0.1, 0.2, 0.3],  # Embedding for index 0
            [0.4, 0.5, 0.6],  # Embedding for index 1
            [0.7, 0.8, 0.9],  # Embedding for index 2
            [0.0, 0.1, 0.2],  # Embedding for index 3
            [0.3, 0.4, 0.5]   # Embedding for index 4
        ])
        self.embedding.weight = nn.Parameter(embedding_weights, requires_grad=False)
        
        # Convolutional layer with predefined weights and biases
        self.conv = nn.Conv1d(in_channels=embedding_dim, out_channels=num_filters, kernel_size=kernel_size, stride=1)
        
        # Manually setting filter weights and biases for reproducibility
        conv_weights = torch.tensor([
            [[0.1, -0.2], [0.4, 0.1], [-0.3, 0.2]],  # Filter 1 weights
            [[0.2, 0.0], [-0.1, 0.3], [0.3, -0.4]]   # Filter 2 weights
        ])
        conv_biases = torch.tensor([0.1, -0.2])  # Bias for each filter
        self.conv.weight = nn.Parameter(conv_weights, requires_grad=False)
        self.conv.bias = nn.Parameter(conv_biases, requires_grad=False)
        
    def forward(self, x):
        # Step 2: Embedding layer
        x = self.embedding(x)  # Shape: (batch_size, max_length, embedding_dim)
        
        # Permute to fit Conv1d requirements: (batch_size, embedding_dim, max_length)
        x = x.permute(0, 2, 1)
        
        # Step 3: Apply Conv1d and ReLU activation
        x = self.conv(x)  # Shape: (batch_size, num_filters, output_length)
        x = F.relu(x)     # Apply ReLU for non-linearity
        
        # Step 4: Apply Max Pooling (manually taking the max along the sequence length dimension)
        # x = x.max(dim=2)[0]  # Shape: (batch_size, num_filters)
        
        return x

# Instantiate the model
model = ExampleTextCNN()

# Define input sequence
input_sequence = torch.tensor([[2, 3, 1, 4]])  # Shape: (batch_size=1, max_length=4)

# Forward pass
output = model(input_sequence)

# Print the output
print("Output after convolution and max pooling:", output)
# Out:
# Output after convolution and max pooling: tensor([[[0.2700, 0.1700, 0.2400],
#          [0.0800, 0.0000, 0.0000]]])
